# %% [markdown]
# # Import Packages

# %%
#数字操作
import math
import numpy as np

#读写数据
import pandas as pd
import os
import csv

#进度条
from tqdm import tqdm

#pytorch
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, random_split

#绘图
from torch.utils.tensorboard import SummaryWriter

# %% [markdown]
# # Some Utility Functions

# %%
def same_seed(seed):
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False #固定训练结果
    np.random.seed(seed)
    torch.manual_seed(seed) #为CPU中设置种子，生成随机数：
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed) #为所有GPU设置种子，生成随机数：

# %%
#分割训练集与验证集
def train_valid_split(data_set, valid_ratio, seed):
    valid_set_size = int(valid_ratio * len(data_set))
    train_set_size = len(data_set) - valid_set_size
    train_set, valid_set = random_split(
        data_set,
        [train_set_size, valid_set_size],
        generator=torch.Generator().manual_seed(seed)
    )
    return np.array(train_set), np.array(valid_set)

# %%
def predict(test_loader, model, device):
    model.eval()
    preds = []
    for x in tqdm(test_loader):
        x = x.to(device)
        with torch.no_grad():
            pred = model(x)
            preds.append(pred.detach().cpu())
    preds = torch.cat(preds, dim=0).numpy()
    return preds

# %% [markdown]
# # Dataset

# %%
#x: Features
#y: Targets, if none, do prediction
class COVID19Dataset(Dataset):
    def __init__(self, x, y=None):
        if y is None:
            self.y = y
        else:
            self.y =torch.FloatTensor(y)
        self.x = torch.FloatTensor(x)
        
    def __getitem__(self, idx):
        if self.y is None:
            return self.x[idx]
        else:
            return self.x[idx], self.y[idx]
    
    def __len__(self):
        return len(self.x)

# %% [markdown]
# # Neural Network Model

# %%
class My_Model(nn.Module):
    def __init__(self, input_dim):
        super(My_Model, self).__init__()
        self.layers = nn.Sequential(
            nn.Linear(input_dim, 16),
            nn.ReLU(),
            nn.Linear(16, 8),
            nn.ReLU(),
            nn.Linear(8, 1)
        )
        
    def forward(self, x):
        x = self.layers(x)
        x = x.squeeze(1) #(b, 1) -> (b)
        return x

# %% [markdown]
# # Feature Selection

# %%
def select_feat(train_data, valid_data, test_data, select_all=True):
    '''Selects useful features to perform regression'''
    y_train, y_valid = train_data[:,-1], valid_data[:,-1]
    raw_x_train, raw_x_valid, raw_x_test = train_data[:,:-1], valid_data[:,:-1], test_data

    if select_all:
        feat_idx = list(range(raw_x_train.shape[1]))
    else:
        feat_idx = [0,1,2,3,4] # TODO: Select suitable feature columns.
        
    return raw_x_train[:,feat_idx], raw_x_valid[:,feat_idx], raw_x_test[:,feat_idx], y_train, y_valid

# %% [markdown]
# # Training Loop

# %%
def trainer(train_loader, valid_loader, model, config, device):
    loss_fn = nn.MSELoss(reduction='mean')
    
    optimizer = torch.optim.SGD(model.parameters(), lr=config['learning_rate'])
    writer = SummaryWriter()
    
    if not os.path.isdir('./models'):
        os.mkdir('./models') #创建文件夹存储model
    
    n_epochs, best_loss, step, early_step_count = config['n_epochs'], math.inf, 0, 0
    
    for epoch in range(n_epochs):
        model.train()
        loss_record = []
        
        #tqdm包可以可视化训练过程
        train_pbar = tqdm(train_loader, position=0, leave=True)
        
        for x, y in train_pbar:
            optimizer.zero_grad()
            x, y = x.to(device), y.to(device)
            pred = model(x)
            loss = loss_fn(pred, y)
            loss.backward()
            optimizer.step()
            step += 1
            #返回一个新的tensor，从当前计算图中分离下来的，
            #但是仍指向原变量的存放位置,不同之处只是requires_grad为false，
            #得到的这个tensor永远不需要计算其梯度，不具有grad
            loss_record.append(loss.detach().item())
            
            # Display current epoch number and loss on tqdm progress bar.
            train_pbar.set_description(f'Epoch [{epoch+1}/{n_epochs}]')
            train_pbar.set_postfix({'loss': loss.detach().item()})
            
        mean_train_loss = sum(loss_record)/len(loss_record)
        writer.add_scalar('Loss/train', mean_train_loss, step)
        
        model.eval()
        loss_record = []
        
        for x, y in valid_loader:
            x, y = x.to(device), y.to(device)
            with torch.no_grad():
                pred = model(x)
                loss = loss_fn(pred, y)
                
            loss_record.append(loss.item())
            
        mean_valid_loss = sum(loss_record)/len(loss_record)
        print(f'Epoch [{epoch+1}/{n_epochs}]: Train loss: {mean_train_loss:.4f}, Valid loss: {mean_valid_loss:.4f}')
        writer.add_scalar('Loss/valid',mean_valid_loss,step)
        
        ###找出每次的epoch训练中最好损失最小的一次，将该次的模型保存
        if mean_valid_loss < best_loss:
            best_loss = mean_valid_loss
            torch.save(model.state_dict(), config['save_path']) #保存最优模型
            print('Saving model with loss {:.3f}...'.format(best_loss))
            early_step_count = 0
        
        else:
            early_step_count += 1
            
        if early_step_count >= config['early_stop']:
            print('\nModel is not improving, so we halt the training session.')
            return

# %% [markdown]
# # Configuration

# %%
device = 'cuda' if torch.cuda.is_available else 'cpu'
config = {
    'seed': 5201314,      # Your seed number, you can pick your lucky number. :)
    'select_all': True,   # Whether to use all features.
    'valid_ratio': 0.2,   # validation_size = train_size * valid_ratio
    'n_epochs': 3000,     # Number of epochs.            
    'batch_size': 256, 
    'learning_rate': 1e-5,              
    'early_stop': 400,    # If model has not improved for this many consecutive epochs, stop training.     
    'save_path': './models/model.ckpt'  # Your model will be saved here.
}

# %% [markdown]
# # DataLoader

# %%
# Set seed for reproducibility
same_seed(config['seed'])


# train_data size: 2699 x 118 (id + 37 states + 16 features x 5 days) 
# test_data size: 1078 x 117 (without last day's positive rate)
train_data, test_data = pd.read_csv('./covid.train_new.csv').values, pd.read_csv('./covid.test_un.csv').values
train_data, valid_data = train_valid_split(train_data, config['valid_ratio'], config['seed'])

# Print out the data size.
print(f"""train_data size: {train_data.shape} 
valid_data size: {valid_data.shape} 
test_data size: {test_data.shape}""")

# Select features
x_train, x_valid, x_test, y_train, y_valid = select_feat(train_data, valid_data, test_data, config['select_all'])

# Print out the number of features.
print(f'number of features: {x_train.shape[1]}')

train_dataset, valid_dataset, test_dataset = COVID19Dataset(x_train, y_train), \
                                            COVID19Dataset(x_valid, y_valid), \
                                            COVID19Dataset(x_test)

# Pytorch data loader loads pytorch dataset into batches.
train_loader = DataLoader(train_dataset, batch_size=config['batch_size'], shuffle=True, pin_memory=True)
valid_loader = DataLoader(valid_dataset, batch_size=config['batch_size'], shuffle=True, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=config['batch_size'], shuffle=False, pin_memory=True)
# Out:
# train_data size: (2160, 118)
# valid_data size: (539, 118)
# test_data size: (1078, 117)
# number of features: 117

# %%
model = My_Model(input_dim=x_train.shape[1]).to(device) # put your model and data on the same computation device.
trainer(train_loader, valid_loader, model, config, device)
# Out:
# Epoch [1/3000]: 100%|███████████████████████████████████████████████████████████| 9/9 [00:03<00:00,  2.59it/s, loss=38]
# Epoch [1/3000]: Train loss: 103.5487, Valid loss: 37.1477
# Saving model with loss 37.148...
# Epoch [2/3000]: 100%|████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 357.32it/s, loss=43.8]
# Epoch [2/3000]: Train loss: 39.7055, Valid loss: 45.0977
# Epoch [3/3000]: 100%|████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 331.20it/s, loss=52.8]
# Epoch [3/3000]: Train loss: 39.3064, Valid loss: 39.7441
# Epoch [4/3000]: 100%|████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 331.76it/s, loss=38.7]
# Epoch [4/3000]: Train loss: 37.7425, Valid loss: 38.4890
# Epoch [5/3000]: 100%|████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 363.26it/s, loss=42.3]
# Epoch [5/3000]: Train loss: 37.2573, Valid loss: 38.8557
# Epoch [6/3000]: 100%|████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 324.55it/s, loss=39.6]
# Epoch [6/3000]: Train loss: 36.6087, Valid loss: 35.5010
# Saving model with loss 35.501...
# Epoch [7/3000]: 100%|████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 353.45it/s, loss=34.2]
# Epoch [7/3000]: Train loss: 35.6021, Valid loss: 36.2732
# Epoch [8/3000]: 100%|████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 349.27it/s, loss=38.8]
# Epoch [8/3000]: Train loss: 35.2390, Valid loss: 33.4652
# Saving model with loss 33.465...
# Epoch [9/3000]: 100%|████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 342.45it/s, loss=31.4]
# Epoch [9/3000]: Train loss: 34.9304, Valid loss: 35.3778
# Epoch [10/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 300.46it/s, loss=30.8]
# Epoch [10/3000]: Train loss: 34.0945, Valid loss: 38.2142
# Epoch [11/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 360.00it/s, loss=39.5]
# Epoch [11/3000]: Train loss: 34.7496, Valid loss: 38.4580
# Epoch [12/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 339.08it/s, loss=32.9]
# Epoch [12/3000]: Train loss: 33.7834, Valid loss: 36.7541
# Epoch [13/3000]: 100%|█████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 360.00it/s, loss=31]
# Epoch [13/3000]: Train loss: 33.5023, Valid loss: 42.4008
# Epoch [14/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 348.05it/s, loss=29.6]
# Epoch [14/3000]: Train loss: 33.3623, Valid loss: 33.9816
# Epoch [15/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 380.46it/s, loss=27.9]
# Epoch [15/3000]: Train loss: 33.2267, Valid loss: 34.2381
# Epoch [16/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 352.61it/s, loss=36.4]
# Epoch [16/3000]: Train loss: 33.0443, Valid loss: 35.6417
# Epoch [17/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 345.14it/s, loss=29.2]
# Epoch [17/3000]: Train loss: 32.3353, Valid loss: 32.0082
# Saving model with loss 32.008...
# Epoch [18/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 347.58it/s, loss=27.5]
# Epoch [18/3000]: Train loss: 32.1923, Valid loss: 35.4451
# Epoch [19/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 367.78it/s, loss=30.9]
# Epoch [19/3000]: Train loss: 32.0578, Valid loss: 31.3537
# Saving model with loss 31.354...
# Epoch [20/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 318.69it/s, loss=34.2]
# Epoch [20/3000]: Train loss: 32.3290, Valid loss: 33.0423
# Epoch [21/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 296.47it/s, loss=36.7]
# Epoch [21/3000]: Train loss: 32.5073, Valid loss: 33.6994
# Epoch [22/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 311.05it/s, loss=31.5]
# Epoch [22/3000]: Train loss: 31.9064, Valid loss: 32.7794
# Epoch [23/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 313.69it/s, loss=37.7]
# Epoch [23/3000]: Train loss: 31.8448, Valid loss: 29.8145
# Saving model with loss 29.814...
# Epoch [24/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 333.10it/s, loss=24.8]
# Epoch [24/3000]: Train loss: 30.8726, Valid loss: 35.1816
# Epoch [25/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 309.51it/s, loss=27.6]
# Epoch [25/3000]: Train loss: 30.9942, Valid loss: 37.7479
# Epoch [26/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 323.99it/s, loss=23.9]
# Epoch [26/3000]: Train loss: 30.5867, Valid loss: 32.4589
# Epoch [27/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 361.10it/s, loss=26.6]
# Epoch [27/3000]: Train loss: 30.7951, Valid loss: 35.0564
# Epoch [28/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 378.04it/s, loss=22.5]
# Epoch [28/3000]: Train loss: 30.1861, Valid loss: 37.8894
# Epoch [29/3000]: 100%|█████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 353.79it/s, loss=25]
# Epoch [29/3000]: Train loss: 30.9424, Valid loss: 34.3145
# Epoch [30/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 376.61it/s, loss=29.3]
# Epoch [30/3000]: Train loss: 29.9176, Valid loss: 27.4309
# Saving model with loss 27.431...
# Epoch [31/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 360.39it/s, loss=27.7]
# Epoch [31/3000]: Train loss: 29.6611, Valid loss: 27.1605
# Saving model with loss 27.161...
# Epoch [32/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 377.85it/s, loss=25.6]
# Epoch [32/3000]: Train loss: 29.6036, Valid loss: 31.4290
# Epoch [33/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 379.76it/s, loss=29.5]
# Epoch [33/3000]: Train loss: 29.7294, Valid loss: 33.2052
# Epoch [34/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 351.05it/s, loss=25.4]
# Epoch [34/3000]: Train loss: 29.2630, Valid loss: 27.9710
# Epoch [35/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 337.91it/s, loss=28.1]
# Epoch [35/3000]: Train loss: 29.2376, Valid loss: 31.1445
# Epoch [36/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 350.22it/s, loss=31.7]
# Epoch [36/3000]: Train loss: 28.9028, Valid loss: 27.8026
# Epoch [37/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 369.07it/s, loss=26.9]
# Epoch [37/3000]: Train loss: 28.6996, Valid loss: 33.4950
# Epoch [38/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 376.96it/s, loss=27.9]
# Epoch [38/3000]: Train loss: 28.1055, Valid loss: 26.8593
# Saving model with loss 26.859...
# Epoch [39/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 342.70it/s, loss=28.9]
# Epoch [39/3000]: Train loss: 28.4954, Valid loss: 30.0609
# Epoch [40/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 333.15it/s, loss=21.8]
# Epoch [40/3000]: Train loss: 27.5078, Valid loss: 33.4954
# Epoch [41/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 370.12it/s, loss=31.4]
# Epoch [41/3000]: Train loss: 28.5258, Valid loss: 29.7864
# Epoch [42/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 375.29it/s, loss=23.7]
# Epoch [42/3000]: Train loss: 27.5484, Valid loss: 30.1368
# Epoch [43/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 374.85it/s, loss=26.7]
# Epoch [43/3000]: Train loss: 28.3052, Valid loss: 29.1022
# Epoch [44/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 315.07it/s, loss=25.3]
# Epoch [44/3000]: Train loss: 27.0455, Valid loss: 28.8261
# Epoch [45/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 329.45it/s, loss=25.4]
# Epoch [45/3000]: Train loss: 26.7512, Valid loss: 30.5502
# Epoch [46/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 307.29it/s, loss=29.9]
# Epoch [46/3000]: Train loss: 27.3592, Valid loss: 27.7422
# Epoch [47/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 348.26it/s, loss=25.5]
# Epoch [47/3000]: Train loss: 26.0576, Valid loss: 26.3784
# Saving model with loss 26.378...
# Epoch [48/3000]: 100%|█████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 385.50it/s, loss=29]
# Epoch [48/3000]: Train loss: 26.3693, Valid loss: 28.4923
# Epoch [49/3000]: 100%|█████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 352.16it/s, loss=29]
# Epoch [49/3000]: Train loss: 26.6165, Valid loss: 24.4012
# Saving model with loss 24.401...
# Epoch [50/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 346.55it/s, loss=20.3]
# Epoch [50/3000]: Train loss: 25.2019, Valid loss: 29.1393
# Epoch [51/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 345.56it/s, loss=34.3]
# Epoch [51/3000]: Train loss: 26.8105, Valid loss: 27.6739
# Epoch [52/3000]: 100%|█████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 335.67it/s, loss=37]
# Epoch [52/3000]: Train loss: 26.3066, Valid loss: 29.5224
# Epoch [53/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 362.41it/s, loss=24.5]
# Epoch [53/3000]: Train loss: 27.3315, Valid loss: 28.2021
# Epoch [54/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 357.27it/s, loss=24.1]
# Epoch [54/3000]: Train loss: 25.6036, Valid loss: 30.6727
# Epoch [55/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 337.81it/s, loss=23.3]
# Epoch [55/3000]: Train loss: 24.6983, Valid loss: 27.3588
# Epoch [56/3000]: 100%|█████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 364.84it/s, loss=24]
# Epoch [56/3000]: Train loss: 23.9072, Valid loss: 24.0416
# Saving model with loss 24.042...
# Epoch [57/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 354.22it/s, loss=25.9]
# Epoch [57/3000]: Train loss: 23.7896, Valid loss: 23.1793
# Saving model with loss 23.179...
# Epoch [58/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 373.54it/s, loss=24.4]
# Epoch [58/3000]: Train loss: 23.2157, Valid loss: 20.8151
# Saving model with loss 20.815...
# Epoch [59/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 296.29it/s, loss=26.5]
# Epoch [59/3000]: Train loss: 24.1416, Valid loss: 22.5531
# Epoch [60/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 355.49it/s, loss=27.1]
# Epoch [60/3000]: Train loss: 26.5021, Valid loss: 26.4286
# Epoch [61/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 353.01it/s, loss=23.3]
# Epoch [61/3000]: Train loss: 23.8570, Valid loss: 23.4042
# Epoch [62/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 366.79it/s, loss=25.7]
# Epoch [62/3000]: Train loss: 25.6452, Valid loss: 31.9381
# Epoch [63/3000]: 100%|█████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 339.43it/s, loss=22]
# Epoch [63/3000]: Train loss: 23.7673, Valid loss: 22.8875
# Epoch [64/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 280.24it/s, loss=28.7]
# Epoch [64/3000]: Train loss: 21.7536, Valid loss: 20.2716
# Saving model with loss 20.272...
# Epoch [65/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 346.15it/s, loss=22.6]
# Epoch [65/3000]: Train loss: 27.8560, Valid loss: 22.2016
# Epoch [66/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 337.10it/s, loss=26.5]
# Epoch [66/3000]: Train loss: 22.2827, Valid loss: 27.7689
# Epoch [67/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 360.00it/s, loss=26.9]
# Epoch [67/3000]: Train loss: 24.4284, Valid loss: 25.6088
# Epoch [68/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 367.43it/s, loss=25.8]
# Epoch [68/3000]: Train loss: 24.6414, Valid loss: 22.6729
# Epoch [69/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 348.77it/s, loss=30.4]
# Epoch [69/3000]: Train loss: 23.8630, Valid loss: 23.5704
# Epoch [70/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 356.79it/s, loss=23.5]
# Epoch [70/3000]: Train loss: 21.8272, Valid loss: 26.2773
# Epoch [71/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 344.01it/s, loss=22.5]
# Epoch [71/3000]: Train loss: 22.9473, Valid loss: 20.8833
# Epoch [72/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 354.54it/s, loss=29.1]
# Epoch [72/3000]: Train loss: 21.1971, Valid loss: 34.8500
# Epoch [73/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 345.67it/s, loss=21.1]
# Epoch [73/3000]: Train loss: 22.5605, Valid loss: 24.8579
# Epoch [74/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 342.31it/s, loss=28.6]
# Epoch [74/3000]: Train loss: 22.5684, Valid loss: 38.1713
# Epoch [75/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 323.75it/s, loss=19.4]
# Epoch [75/3000]: Train loss: 21.5842, Valid loss: 25.1153
# Epoch [76/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 340.67it/s, loss=14.6]
# Epoch [76/3000]: Train loss: 24.5673, Valid loss: 19.8389
# Saving model with loss 19.839...
# Epoch [77/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 346.16it/s, loss=29.6]
# Epoch [77/3000]: Train loss: 22.7350, Valid loss: 28.8679
# Epoch [78/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 322.37it/s, loss=20.5]
# Epoch [78/3000]: Train loss: 19.2625, Valid loss: 25.9041
# Epoch [79/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 360.43it/s, loss=26.9]
# Epoch [79/3000]: Train loss: 22.5323, Valid loss: 20.6490
# Epoch [80/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 339.21it/s, loss=19.9]
# Epoch [80/3000]: Train loss: 21.8587, Valid loss: 27.7833
# Epoch [81/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 349.41it/s, loss=19.6]
# Epoch [81/3000]: Train loss: 18.5464, Valid loss: 20.0300
# Epoch [82/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 310.27it/s, loss=21.2]
# Epoch [82/3000]: Train loss: 23.3429, Valid loss: 20.4240
# Epoch [83/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 355.95it/s, loss=22.5]
# Epoch [83/3000]: Train loss: 22.5567, Valid loss: 28.4864
# Epoch [84/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 361.49it/s, loss=19.7]
# Epoch [84/3000]: Train loss: 20.2794, Valid loss: 16.5265
# Saving model with loss 16.527...
# Epoch [85/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 321.43it/s, loss=16.4]
# Epoch [85/3000]: Train loss: 20.6940, Valid loss: 15.2722
# Saving model with loss 15.272...
# Epoch [86/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 319.99it/s, loss=15.2]
# Epoch [86/3000]: Train loss: 24.2882, Valid loss: 23.9613
# Epoch [87/3000]: 100%|█████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 330.31it/s, loss=20]
# Epoch [87/3000]: Train loss: 19.4610, Valid loss: 25.6218
# Epoch [88/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 320.06it/s, loss=21.2]
# Epoch [88/3000]: Train loss: 19.5479, Valid loss: 18.6188
# Epoch [89/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 348.18it/s, loss=24.2]
# Epoch [89/3000]: Train loss: 19.3475, Valid loss: 33.5352
# Epoch [90/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 364.11it/s, loss=19.9]
# Epoch [90/3000]: Train loss: 18.1683, Valid loss: 23.6637
# Epoch [91/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 317.85it/s, loss=13.9]
# Epoch [91/3000]: Train loss: 22.4920, Valid loss: 17.1129
# Epoch [92/3000]: 100%|█████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 335.98it/s, loss=17]
# Epoch [92/3000]: Train loss: 17.2423, Valid loss: 16.8970
# Epoch [93/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 353.15it/s, loss=14.4]
# Epoch [93/3000]: Train loss: 19.7394, Valid loss: 17.8076
# Epoch [94/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 352.52it/s, loss=19.1]
# Epoch [94/3000]: Train loss: 19.2019, Valid loss: 34.6066
# Epoch [95/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 352.39it/s, loss=21.3]
# Epoch [95/3000]: Train loss: 19.6025, Valid loss: 19.8583
# Epoch [96/3000]: 100%|█████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 351.20it/s, loss=16]
# Epoch [96/3000]: Train loss: 17.5655, Valid loss: 25.0066
# Epoch [97/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 382.19it/s, loss=16.9]
# Epoch [97/3000]: Train loss: 20.0996, Valid loss: 18.3071
# Epoch [98/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 340.80it/s, loss=12.5]
# Epoch [98/3000]: Train loss: 18.2996, Valid loss: 14.1390
# Saving model with loss 14.139...
# Epoch [99/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 373.26it/s, loss=19.3]
# Epoch [99/3000]: Train loss: 18.1864, Valid loss: 20.3048
# Epoch [100/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 360.00it/s, loss=17.3]
# Epoch [100/3000]: Train loss: 19.4798, Valid loss: 19.3279
# Epoch [101/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 333.40it/s, loss=26.7]
# Epoch [101/3000]: Train loss: 18.7876, Valid loss: 18.5169
# Epoch [102/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 332.89it/s, loss=14.2]
# Epoch [102/3000]: Train loss: 17.2745, Valid loss: 13.2875
# Saving model with loss 13.288...
# Epoch [103/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 304.89it/s, loss=22.7]
# Epoch [103/3000]: Train loss: 20.7201, Valid loss: 18.8342
# Epoch [104/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 312.40it/s, loss=27.2]
# Epoch [104/3000]: Train loss: 18.5582, Valid loss: 40.6147
# Epoch [105/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 302.99it/s, loss=36.5]
# Epoch [105/3000]: Train loss: 19.6770, Valid loss: 16.4091
# Epoch [106/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 276.99it/s, loss=13.6]
# Epoch [106/3000]: Train loss: 15.0727, Valid loss: 14.6789
# Epoch [107/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 289.41it/s, loss=17.9]
# Epoch [107/3000]: Train loss: 18.8017, Valid loss: 22.7543
# Epoch [108/3000]: 100%|████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 315.63it/s, loss=28]
# Epoch [108/3000]: Train loss: 17.5038, Valid loss: 58.3017
# Epoch [109/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 328.45it/s, loss=11.2]
# Epoch [109/3000]: Train loss: 17.2307, Valid loss: 20.9370
# Epoch [110/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 363.48it/s, loss=18.1]
# Epoch [110/3000]: Train loss: 17.2525, Valid loss: 16.7923
# Epoch [111/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 339.96it/s, loss=17.8]
# Epoch [111/3000]: Train loss: 19.8207, Valid loss: 13.9799
# Epoch [112/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 350.18it/s, loss=20.5]
# Epoch [112/3000]: Train loss: 15.2640, Valid loss: 54.3954
# Epoch [113/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 334.95it/s, loss=32.4]
# Epoch [113/3000]: Train loss: 19.8517, Valid loss: 14.4580
# Epoch [114/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 331.55it/s, loss=13.5]
# Epoch [114/3000]: Train loss: 17.0379, Valid loss: 12.3685
# Saving model with loss 12.369...
# Epoch [115/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 271.52it/s, loss=11.1]
# Epoch [115/3000]: Train loss: 18.5209, Valid loss: 11.7046
# Saving model with loss 11.705...
# Epoch [116/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 333.33it/s, loss=11.9]
# Epoch [116/3000]: Train loss: 17.6082, Valid loss: 13.6840
# Epoch [117/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 375.00it/s, loss=10.6]
# Epoch [117/3000]: Train loss: 16.0072, Valid loss: 12.1882
# Epoch [118/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 315.09it/s, loss=16.8]
# Epoch [118/3000]: Train loss: 16.7461, Valid loss: 22.3198
# Epoch [119/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 346.19it/s, loss=10.8]
# Epoch [119/3000]: Train loss: 18.5048, Valid loss: 12.6192
# Epoch [120/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 335.29it/s, loss=14.4]
# Epoch [120/3000]: Train loss: 16.8370, Valid loss: 16.6038
# Epoch [121/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 340.07it/s, loss=24.3]
# Epoch [121/3000]: Train loss: 17.0807, Valid loss: 14.3508
# Epoch [122/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 326.92it/s, loss=8.73]
# Epoch [122/3000]: Train loss: 15.7920, Valid loss: 12.5086
# Epoch [123/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 348.73it/s, loss=9.81]
# Epoch [123/3000]: Train loss: 18.6016, Valid loss: 10.9723
# Saving model with loss 10.972...
# Epoch [124/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 284.38it/s, loss=15.2]
# Epoch [124/3000]: Train loss: 14.6564, Valid loss: 33.5259
# Epoch [125/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 358.63it/s, loss=14.1]
# Epoch [125/3000]: Train loss: 19.5553, Valid loss: 12.6167
# Epoch [126/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 358.09it/s, loss=44.1]
# Epoch [126/3000]: Train loss: 15.4481, Valid loss: 78.4935
# Epoch [127/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 352.83it/s, loss=14.9]
# Epoch [127/3000]: Train loss: 23.3929, Valid loss: 14.1642
# Epoch [128/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 362.70it/s, loss=13.1]
# Epoch [128/3000]: Train loss: 16.2625, Valid loss: 18.6365
# Epoch [129/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 363.01it/s, loss=10.9]
# Epoch [129/3000]: Train loss: 13.4513, Valid loss: 12.2953
# Epoch [130/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 333.58it/s, loss=10.2]
# Epoch [130/3000]: Train loss: 15.3787, Valid loss: 10.9896
# Epoch [131/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 343.73it/s, loss=15.1]
# Epoch [131/3000]: Train loss: 15.8753, Valid loss: 16.1391
# Epoch [132/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 325.09it/s, loss=16.2]
# Epoch [132/3000]: Train loss: 16.0627, Valid loss: 12.0305
# Epoch [133/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 362.45it/s, loss=11.5]
# Epoch [133/3000]: Train loss: 15.3818, Valid loss: 12.1071
# Epoch [134/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 360.92it/s, loss=12.7]
# Epoch [134/3000]: Train loss: 17.8029, Valid loss: 13.3877
# Epoch [135/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 340.38it/s, loss=16.3]
# Epoch [135/3000]: Train loss: 17.1645, Valid loss: 13.9224
# Epoch [136/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 359.04it/s, loss=11.5]
# Epoch [136/3000]: Train loss: 13.1383, Valid loss: 17.8489
# Epoch [137/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 335.97it/s, loss=46.1]
# Epoch [137/3000]: Train loss: 20.1633, Valid loss: 16.8431
# Epoch [138/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 358.96it/s, loss=8.97]
# Epoch [138/3000]: Train loss: 12.1354, Valid loss: 8.6724
# Saving model with loss 8.672...
# Epoch [139/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 365.75it/s, loss=12.6]
# Epoch [139/3000]: Train loss: 15.6424, Valid loss: 9.8622
# Epoch [140/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 349.61it/s, loss=12.4]
# Epoch [140/3000]: Train loss: 17.7734, Valid loss: 11.3049
# Epoch [141/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 331.25it/s, loss=19.9]
# Epoch [141/3000]: Train loss: 15.8752, Valid loss: 15.5243
# Epoch [142/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 347.70it/s, loss=10.3]
# Epoch [142/3000]: Train loss: 10.1601, Valid loss: 10.0183
# Epoch [143/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 353.03it/s, loss=11.4]
# Epoch [143/3000]: Train loss: 22.5814, Valid loss: 13.4086
# Epoch [144/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 349.45it/s, loss=56.6]
# Epoch [144/3000]: Train loss: 20.5106, Valid loss: 17.3849
# Epoch [145/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 340.62it/s, loss=11.5]
# Epoch [145/3000]: Train loss: 13.7109, Valid loss: 12.1403
# Epoch [146/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 351.64it/s, loss=9.2]
# Epoch [146/3000]: Train loss: 16.7916, Valid loss: 10.3344
# Epoch [147/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 320.00it/s, loss=10.8]
# Epoch [147/3000]: Train loss: 14.5501, Valid loss: 10.8440
# Epoch [148/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 341.52it/s, loss=7.97]
# Epoch [148/3000]: Train loss: 13.4650, Valid loss: 10.0031
# Epoch [149/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 332.15it/s, loss=8.58]
# Epoch [149/3000]: Train loss: 14.6884, Valid loss: 8.1817
# Saving model with loss 8.182...
# Epoch [150/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 340.76it/s, loss=9.91]
# Epoch [150/3000]: Train loss: 13.7568, Valid loss: 14.0401
# Epoch [151/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 345.99it/s, loss=19.3]
# Epoch [151/3000]: Train loss: 15.7546, Valid loss: 11.2280
# Epoch [152/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 328.77it/s, loss=9.05]
# Epoch [152/3000]: Train loss: 15.9608, Valid loss: 12.1030
# Epoch [153/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 314.29it/s, loss=9.46]
# Epoch [153/3000]: Train loss: 13.4056, Valid loss: 12.5985
# Epoch [154/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 342.64it/s, loss=10.4]
# Epoch [154/3000]: Train loss: 13.5582, Valid loss: 9.6227
# Epoch [155/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 312.06it/s, loss=34.9]
# Epoch [155/3000]: Train loss: 15.2285, Valid loss: 12.0668
# Epoch [156/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 342.63it/s, loss=9.62]
# Epoch [156/3000]: Train loss: 14.9799, Valid loss: 14.1461
# Epoch [157/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 306.24it/s, loss=8.54]
# Epoch [157/3000]: Train loss: 13.7177, Valid loss: 10.9351
# Epoch [158/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 297.08it/s, loss=18.4]
# Epoch [158/3000]: Train loss: 14.8853, Valid loss: 33.9964
# Epoch [159/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 348.25it/s, loss=33.4]
# Epoch [159/3000]: Train loss: 15.9771, Valid loss: 11.0461
# Epoch [160/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 329.45it/s, loss=8.53]
# Epoch [160/3000]: Train loss: 15.2055, Valid loss: 12.0997
# Epoch [161/3000]: 100%|████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 345.30it/s, loss=13]
# Epoch [161/3000]: Train loss: 14.2351, Valid loss: 12.3233
# Epoch [162/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 348.51it/s, loss=12.9]
# Epoch [162/3000]: Train loss: 14.6536, Valid loss: 17.7321
# Epoch [163/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 281.55it/s, loss=11.8]
# Epoch [163/3000]: Train loss: 15.6260, Valid loss: 11.8459
# Epoch [164/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 338.60it/s, loss=10.4]
# Epoch [164/3000]: Train loss: 12.8012, Valid loss: 30.8938
# Epoch [165/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 316.25it/s, loss=38.8]
# Epoch [165/3000]: Train loss: 16.4317, Valid loss: 13.2538
# Epoch [166/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 317.49it/s, loss=30.9]
# Epoch [166/3000]: Train loss: 12.2410, Valid loss: 38.2958
# Epoch [167/3000]: 100%|████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 331.63it/s, loss=11]
# Epoch [167/3000]: Train loss: 24.3651, Valid loss: 14.5408
# Epoch [168/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 302.23it/s, loss=7.84]
# Epoch [168/3000]: Train loss: 10.6631, Valid loss: 12.4569
# Epoch [169/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 285.12it/s, loss=6.42]
# Epoch [169/3000]: Train loss: 15.5550, Valid loss: 9.3895
# Epoch [170/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 315.68it/s, loss=28.2]
# Epoch [170/3000]: Train loss: 15.6707, Valid loss: 56.4237
# Epoch [171/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 330.59it/s, loss=8.29]
# Epoch [171/3000]: Train loss: 15.9804, Valid loss: 11.9347
# Epoch [172/3000]: 100%|████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 362.74it/s, loss=11]
# Epoch [172/3000]: Train loss: 16.3499, Valid loss: 11.3664
# Epoch [173/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 329.57it/s, loss=25.6]
# Epoch [173/3000]: Train loss: 15.5000, Valid loss: 11.4583
# Epoch [174/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 334.43it/s, loss=14.6]
# Epoch [174/3000]: Train loss: 14.5699, Valid loss: 20.0853
# Epoch [175/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 369.83it/s, loss=32.5]
# Epoch [175/3000]: Train loss: 16.3913, Valid loss: 14.6003
# Epoch [176/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 333.42it/s, loss=13.5]
# Epoch [176/3000]: Train loss: 10.8820, Valid loss: 17.4963
# Epoch [177/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 359.71it/s, loss=9.63]
# Epoch [177/3000]: Train loss: 14.9114, Valid loss: 14.7316
# Epoch [178/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 37.76it/s, loss=11.5]
# Epoch [178/3000]: Train loss: 12.7344, Valid loss: 13.4683
# Epoch [179/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 318.41it/s, loss=5.4]
# Epoch [179/3000]: Train loss: 11.5191, Valid loss: 7.1699
# Saving model with loss 7.170...
# Epoch [180/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 343.01it/s, loss=7.38]
# Epoch [180/3000]: Train loss: 12.9554, Valid loss: 11.6986
# Epoch [181/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 354.86it/s, loss=11.3]
# Epoch [181/3000]: Train loss: 16.0426, Valid loss: 9.6679
# Epoch [182/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 334.81it/s, loss=7.79]
# Epoch [182/3000]: Train loss: 12.0344, Valid loss: 8.6936
# Epoch [183/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 363.39it/s, loss=8.31]
# Epoch [183/3000]: Train loss: 12.3082, Valid loss: 8.3098
# Epoch [184/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 324.73it/s, loss=32.2]
# Epoch [184/3000]: Train loss: 9.6797, Valid loss: 70.6612
# Epoch [185/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 339.20it/s, loss=15.9]
# Epoch [185/3000]: Train loss: 40.1948, Valid loss: 14.7432
# Epoch [186/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 339.84it/s, loss=10.3]
# Epoch [186/3000]: Train loss: 13.4505, Valid loss: 13.4904
# Epoch [187/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 307.43it/s, loss=7.92]
# Epoch [187/3000]: Train loss: 15.3581, Valid loss: 12.5302
# Epoch [188/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 352.02it/s, loss=11.5]
# Epoch [188/3000]: Train loss: 16.3941, Valid loss: 10.5176
# Epoch [189/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 374.31it/s, loss=12.9]
# Epoch [189/3000]: Train loss: 10.9783, Valid loss: 17.0177
# Epoch [190/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 347.98it/s, loss=13.4]
# Epoch [190/3000]: Train loss: 16.7761, Valid loss: 13.5317
# Epoch [191/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 335.16it/s, loss=12.8]
# Epoch [191/3000]: Train loss: 13.6381, Valid loss: 17.4258
# Epoch [192/3000]: 100%|████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 289.22it/s, loss=11]
# Epoch [192/3000]: Train loss: 12.4962, Valid loss: 11.0949
# Epoch [193/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 360.00it/s, loss=12.9]
# Epoch [193/3000]: Train loss: 14.5536, Valid loss: 28.9644
# Epoch [194/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 375.00it/s, loss=10.5]
# Epoch [194/3000]: Train loss: 13.8821, Valid loss: 13.0867
# Epoch [195/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 320.29it/s, loss=9.77]
# Epoch [195/3000]: Train loss: 12.8787, Valid loss: 18.2303
# Epoch [196/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 344.80it/s, loss=16.8]
# Epoch [196/3000]: Train loss: 14.3471, Valid loss: 8.8521
# Epoch [197/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 354.31it/s, loss=12.2]
# Epoch [197/3000]: Train loss: 11.4424, Valid loss: 27.5032
# Epoch [198/3000]: 100%|████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 347.51it/s, loss=10]
# Epoch [198/3000]: Train loss: 14.4737, Valid loss: 15.2160
# Epoch [199/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 357.76it/s, loss=11.9]
# Epoch [199/3000]: Train loss: 17.2162, Valid loss: 13.7456
# Epoch [200/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 375.76it/s, loss=8.33]
# Epoch [200/3000]: Train loss: 11.3332, Valid loss: 18.5963
# Epoch [201/3000]: 100%|█████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 348.05it/s, loss=9]
# Epoch [201/3000]: Train loss: 14.2422, Valid loss: 16.2034
# Epoch [202/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 353.74it/s, loss=30.2]
# Epoch [202/3000]: Train loss: 12.0696, Valid loss: 7.4749
# Epoch [203/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 350.96it/s, loss=14.3]
# Epoch [203/3000]: Train loss: 15.0738, Valid loss: 12.0974
# Epoch [204/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 361.83it/s, loss=10.9]
# Epoch [204/3000]: Train loss: 9.9327, Valid loss: 20.4160
# Epoch [205/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 358.66it/s, loss=12.6]
# Epoch [205/3000]: Train loss: 17.8102, Valid loss: 9.2419
# Epoch [206/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 341.68it/s, loss=11.3]
# Epoch [206/3000]: Train loss: 10.7981, Valid loss: 26.6192
# Epoch [207/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 354.65it/s, loss=7.82]
# Epoch [207/3000]: Train loss: 14.3586, Valid loss: 15.6177
# Epoch [208/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 323.05it/s, loss=8.05]
# Epoch [208/3000]: Train loss: 12.6921, Valid loss: 14.3521
# Epoch [209/3000]: 100%|████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 315.88it/s, loss=53]
# Epoch [209/3000]: Train loss: 15.7667, Valid loss: 8.1786
# Epoch [210/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 346.16it/s, loss=14.3]
# Epoch [210/3000]: Train loss: 9.8432, Valid loss: 34.2216
# Epoch [211/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 339.36it/s, loss=8.37]
# Epoch [211/3000]: Train loss: 16.2302, Valid loss: 6.8134
# Saving model with loss 6.813...
# Epoch [212/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 354.94it/s, loss=8.08]
# Epoch [212/3000]: Train loss: 8.5376, Valid loss: 13.9761
# Epoch [213/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 350.83it/s, loss=12.7]
# Epoch [213/3000]: Train loss: 14.7242, Valid loss: 29.0733
# Epoch [214/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 353.72it/s, loss=9.22]
# Epoch [214/3000]: Train loss: 10.1745, Valid loss: 28.5892
# Epoch [215/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 362.76it/s, loss=7.77]
# Epoch [215/3000]: Train loss: 8.5968, Valid loss: 9.6128
# Epoch [216/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 358.59it/s, loss=11.7]
# Epoch [216/3000]: Train loss: 21.1039, Valid loss: 14.4452
# Epoch [217/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 361.32it/s, loss=15.8]
# Epoch [217/3000]: Train loss: 10.7095, Valid loss: 8.6579
# Epoch [218/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 356.15it/s, loss=7.53]
# Epoch [218/3000]: Train loss: 10.5200, Valid loss: 7.1986
# Epoch [219/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 345.02it/s, loss=7.71]
# Epoch [219/3000]: Train loss: 8.5331, Valid loss: 14.1657
# Epoch [220/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 350.93it/s, loss=6.69]
# Epoch [220/3000]: Train loss: 10.2445, Valid loss: 10.6417
# Epoch [221/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 335.75it/s, loss=5.91]
# Epoch [221/3000]: Train loss: 11.5233, Valid loss: 14.9520
# Epoch [222/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 285.94it/s, loss=7.21]
# Epoch [222/3000]: Train loss: 15.9112, Valid loss: 6.6554
# Saving model with loss 6.655...
# Epoch [223/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 287.93it/s, loss=26.4]
# Epoch [223/3000]: Train loss: 12.7123, Valid loss: 8.4628
# Epoch [224/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 275.77it/s, loss=17.1]
# Epoch [224/3000]: Train loss: 14.6322, Valid loss: 10.3743
# Epoch [225/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 299.61it/s, loss=19.7]
# Epoch [225/3000]: Train loss: 11.3131, Valid loss: 10.5950
# Epoch [226/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 282.48it/s, loss=10.2]
# Epoch [226/3000]: Train loss: 9.6590, Valid loss: 6.0729
# Saving model with loss 6.073...
# Epoch [227/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 266.82it/s, loss=16.7]
# Epoch [227/3000]: Train loss: 9.8574, Valid loss: 47.2155
# Epoch [228/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 307.32it/s, loss=11.9]
# Epoch [228/3000]: Train loss: 13.6732, Valid loss: 14.6425
# Epoch [229/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 323.14it/s, loss=17.9]
# Epoch [229/3000]: Train loss: 12.8839, Valid loss: 15.9611
# Epoch [230/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 307.12it/s, loss=11.2]
# Epoch [230/3000]: Train loss: 14.9833, Valid loss: 9.0325
# Epoch [231/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 302.39it/s, loss=4.74]
# Epoch [231/3000]: Train loss: 9.6285, Valid loss: 7.0278
# Epoch [232/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 278.66it/s, loss=25.5]
# Epoch [232/3000]: Train loss: 11.2534, Valid loss: 7.2027
# Epoch [233/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 324.39it/s, loss=8.74]
# Epoch [233/3000]: Train loss: 11.1158, Valid loss: 6.1235
# Epoch [234/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 327.99it/s, loss=15.8]
# Epoch [234/3000]: Train loss: 7.4199, Valid loss: 15.6271
# Epoch [235/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 336.77it/s, loss=13.9]
# Epoch [235/3000]: Train loss: 13.7506, Valid loss: 35.9808
# Epoch [236/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 304.99it/s, loss=8.73]
# Epoch [236/3000]: Train loss: 12.2460, Valid loss: 10.7127
# Epoch [237/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 319.01it/s, loss=18.1]
# Epoch [237/3000]: Train loss: 10.6613, Valid loss: 10.1823
# Epoch [238/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 294.33it/s, loss=7.98]
# Epoch [238/3000]: Train loss: 9.7928, Valid loss: 8.4456
# Epoch [239/3000]: 100%|████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 330.30it/s, loss=28]
# Epoch [239/3000]: Train loss: 14.3206, Valid loss: 14.0804
# Epoch [240/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 326.67it/s, loss=8.68]
# Epoch [240/3000]: Train loss: 12.3652, Valid loss: 17.7474
# Epoch [241/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 354.71it/s, loss=6.26]
# Epoch [241/3000]: Train loss: 14.0744, Valid loss: 8.8945
# Epoch [242/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 330.19it/s, loss=6.26]
# Epoch [242/3000]: Train loss: 10.0685, Valid loss: 7.3997
# Epoch [243/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 349.11it/s, loss=17.1]
# Epoch [243/3000]: Train loss: 8.0744, Valid loss: 10.4620
# Epoch [244/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 313.19it/s, loss=5.86]
# Epoch [244/3000]: Train loss: 9.1055, Valid loss: 7.7757
# Epoch [245/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 324.36it/s, loss=8.09]
# Epoch [245/3000]: Train loss: 9.8035, Valid loss: 9.2440
# Epoch [246/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 324.36it/s, loss=12.5]
# Epoch [246/3000]: Train loss: 10.2518, Valid loss: 22.2145
# Epoch [247/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 323.95it/s, loss=7.58]
# Epoch [247/3000]: Train loss: 14.4135, Valid loss: 7.9463
# Epoch [248/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 352.09it/s, loss=5.96]
# Epoch [248/3000]: Train loss: 11.8548, Valid loss: 6.3842
# Epoch [249/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 348.59it/s, loss=6.1]
# Epoch [249/3000]: Train loss: 8.7325, Valid loss: 7.8085
# Epoch [250/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 324.10it/s, loss=6.8]
# Epoch [250/3000]: Train loss: 8.7967, Valid loss: 6.4558
# Epoch [251/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 339.27it/s, loss=6.44]
# Epoch [251/3000]: Train loss: 8.6131, Valid loss: 5.1434
# Saving model with loss 5.143...
# Epoch [252/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 344.43it/s, loss=5.26]
# Epoch [252/3000]: Train loss: 9.7348, Valid loss: 6.8808
# Epoch [253/3000]: 100%|███████████████████████████████████████████████████████| 9/9 [00:00<00:00, 333.33it/s, loss=6.1]
# Epoch [253/3000]: Train loss: 10.5036, Valid loss: 7.9907
# Epoch [254/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 322.12it/s, loss=7.42]
# Epoch [254/3000]: Train loss: 10.8650, Valid loss: 9.3550
# Epoch [255/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 302.67it/s, loss=6.51]
# Epoch [255/3000]: Train loss: 10.9453, Valid loss: 5.6192
# Epoch [256/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 321.77it/s, loss=7.93]
# Epoch [256/3000]: Train loss: 9.3909, Valid loss: 19.8792
# Epoch [257/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 329.60it/s, loss=6.25]
# Epoch [257/3000]: Train loss: 10.5494, Valid loss: 5.9910
# Epoch [258/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 326.22it/s, loss=6.23]
# Epoch [258/3000]: Train loss: 14.8972, Valid loss: 7.4059
# Epoch [259/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 340.35it/s, loss=8.54]
# Epoch [259/3000]: Train loss: 10.2231, Valid loss: 6.0714
# Epoch [260/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 332.17it/s, loss=8.19]
# Epoch [260/3000]: Train loss: 7.5082, Valid loss: 14.6812
# Epoch [261/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 329.37it/s, loss=6.55]
# Epoch [261/3000]: Train loss: 13.2261, Valid loss: 5.9963
# Epoch [262/3000]: 100%|████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 338.92it/s, loss=12]
# Epoch [262/3000]: Train loss: 9.4310, Valid loss: 39.8175
# Epoch [263/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 328.13it/s, loss=7.99]
# Epoch [263/3000]: Train loss: 9.5088, Valid loss: 19.8819
# ...
# Epoch [2911/3000]: Train loss: 3.7340, Valid loss: 3.2179
# Epoch [2912/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 293.14it/s, loss=3.89]
# Epoch [2912/3000]: Train loss: 3.4358, Valid loss: 4.0636
# Epoch [2913/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 304.36it/s, loss=4.09]
# Epoch [2913/3000]: Train loss: 4.4501, Valid loss: 3.3240
# Epoch [2914/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 308.18it/s, loss=2.84]
# Epoch [2914/3000]: Train loss: 3.4773, Valid loss: 3.0752
# Epoch [2915/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 307.48it/s, loss=5.24]
# Epoch [2915/3000]: Train loss: 3.2488, Valid loss: 4.5342
# Epoch [2916/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 303.43it/s, loss=3.57]
# Epoch [2916/3000]: Train loss: 4.7920, Valid loss: 4.4518
# Epoch [2917/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 276.48it/s, loss=4.57]
# Epoch [2917/3000]: Train loss: 3.5650, Valid loss: 3.7496
# Epoch [2918/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 294.94it/s, loss=2.56]
# Epoch [2918/3000]: Train loss: 3.9898, Valid loss: 3.0811
# Epoch [2919/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 314.94it/s, loss=2.82]
# Epoch [2919/3000]: Train loss: 2.8052, Valid loss: 3.2466
# Epoch [2920/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 298.04it/s, loss=3.08]
# Epoch [2920/3000]: Train loss: 3.3838, Valid loss: 3.7845
# Epoch [2921/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 302.33it/s, loss=5.21]
# Epoch [2921/3000]: Train loss: 5.2783, Valid loss: 3.1054
# Epoch [2922/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 300.01it/s, loss=2.79]
# Epoch [2922/3000]: Train loss: 2.8352, Valid loss: 3.0731
# Epoch [2923/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 346.16it/s, loss=4.05]
# Epoch [2923/3000]: Train loss: 4.0906, Valid loss: 2.8978
# Epoch [2924/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 333.55it/s, loss=4.01]
# Epoch [2924/3000]: Train loss: 3.1856, Valid loss: 3.7156
# Epoch [2925/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 311.19it/s, loss=3.25]
# Epoch [2925/3000]: Train loss: 5.0900, Valid loss: 3.0007
# Epoch [2926/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 312.85it/s, loss=2.37]
# Epoch [2926/3000]: Train loss: 2.9738, Valid loss: 2.8074
# Epoch [2927/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 306.62it/s, loss=5.48]
# Epoch [2927/3000]: Train loss: 4.7674, Valid loss: 3.7898
# Epoch [2928/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 413.82it/s, loss=3.43]
# Epoch [2928/3000]: Train loss: 3.8137, Valid loss: 3.1278
# Epoch [2929/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 351.40it/s, loss=5.38]
# Epoch [2929/3000]: Train loss: 3.7160, Valid loss: 3.1373
# Epoch [2930/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 301.18it/s, loss=2.65]
# Epoch [2930/3000]: Train loss: 3.1960, Valid loss: 3.3432
# Epoch [2931/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 310.42it/s, loss=3.28]
# Epoch [2931/3000]: Train loss: 2.9591, Valid loss: 3.3478
# Epoch [2932/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 336.20it/s, loss=2.74]
# Epoch [2932/3000]: Train loss: 2.9345, Valid loss: 4.9686
# Epoch [2933/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 404.22it/s, loss=5.42]
# Epoch [2933/3000]: Train loss: 4.4045, Valid loss: 3.9528
# Epoch [2934/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 287.04it/s, loss=5.24]
# Epoch [2934/3000]: Train loss: 3.9326, Valid loss: 6.0327
# Epoch [2935/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 318.93it/s, loss=4.47]
# Epoch [2935/3000]: Train loss: 4.9844, Valid loss: 3.3798
# Epoch [2936/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 312.03it/s, loss=3.32]
# Epoch [2936/3000]: Train loss: 2.9380, Valid loss: 2.6215
# Epoch [2937/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 387.59it/s, loss=3.47]
# Epoch [2937/3000]: Train loss: 2.8012, Valid loss: 3.4909
# Epoch [2938/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 290.04it/s, loss=4.39]
# Epoch [2938/3000]: Train loss: 4.6065, Valid loss: 4.2537
# Epoch [2939/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 364.71it/s, loss=3.07]
# Epoch [2939/3000]: Train loss: 3.7836, Valid loss: 3.1261
# Epoch [2940/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 373.16it/s, loss=2.89]
# Epoch [2940/3000]: Train loss: 2.7919, Valid loss: 2.3296
# Saving model with loss 2.330...
# Epoch [2941/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 385.23it/s, loss=6.81]
# Epoch [2941/3000]: Train loss: 4.3239, Valid loss: 4.8524
# Epoch [2942/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 360.85it/s, loss=2.86]
# Epoch [2942/3000]: Train loss: 3.7247, Valid loss: 3.0810
# Epoch [2943/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 352.85it/s, loss=4.11]
# Epoch [2943/3000]: Train loss: 4.0230, Valid loss: 3.6995
# Epoch [2944/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 309.32it/s, loss=2.77]
# Epoch [2944/3000]: Train loss: 3.8121, Valid loss: 2.9036
# Epoch [2945/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 317.25it/s, loss=7.01]
# Epoch [2945/3000]: Train loss: 4.0663, Valid loss: 4.6001
# Epoch [2946/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 305.65it/s, loss=2.75]
# Epoch [2946/3000]: Train loss: 2.9381, Valid loss: 2.8327
# Epoch [2947/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 288.63it/s, loss=8.23]
# Epoch [2947/3000]: Train loss: 4.1009, Valid loss: 5.8589
# Epoch [2948/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 273.24it/s, loss=3.22]
# Epoch [2948/3000]: Train loss: 4.4862, Valid loss: 2.7914
# Epoch [2949/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 281.25it/s, loss=3.2]
# Epoch [2949/3000]: Train loss: 3.6912, Valid loss: 5.2554
# Epoch [2950/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 301.32it/s, loss=7.12]
# Epoch [2950/3000]: Train loss: 4.2620, Valid loss: 4.2766
# Epoch [2951/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 311.39it/s, loss=3.13]
# Epoch [2951/3000]: Train loss: 3.5908, Valid loss: 3.0538
# Epoch [2952/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 329.15it/s, loss=3.04]
# Epoch [2952/3000]: Train loss: 2.8525, Valid loss: 4.3974
# Epoch [2953/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 305.22it/s, loss=3.1]
# Epoch [2953/3000]: Train loss: 4.9142, Valid loss: 4.7839
# Epoch [2954/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 292.96it/s, loss=3.29]
# Epoch [2954/3000]: Train loss: 3.3518, Valid loss: 3.0902
# Epoch [2955/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 284.73it/s, loss=3.84]
# Epoch [2955/3000]: Train loss: 4.1248, Valid loss: 4.4548
# Epoch [2956/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 293.52it/s, loss=2.43]
# Epoch [2956/3000]: Train loss: 3.3329, Valid loss: 3.3203
# Epoch [2957/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 346.16it/s, loss=2.77]
# Epoch [2957/3000]: Train loss: 3.3720, Valid loss: 3.9494
# Epoch [2958/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 356.12it/s, loss=3.2]
# Epoch [2958/3000]: Train loss: 2.8168, Valid loss: 3.7005
# Epoch [2959/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 330.48it/s, loss=2.79]
# Epoch [2959/3000]: Train loss: 3.3279, Valid loss: 3.0432
# Epoch [2960/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 315.99it/s, loss=2.87]
# Epoch [2960/3000]: Train loss: 3.8948, Valid loss: 4.7646
# Epoch [2961/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 321.55it/s, loss=4.14]
# Epoch [2961/3000]: Train loss: 3.2555, Valid loss: 4.8724
# Epoch [2962/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 324.18it/s, loss=3.21]
# Epoch [2962/3000]: Train loss: 5.1161, Valid loss: 4.1894
# Epoch [2963/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 321.06it/s, loss=3.72]
# Epoch [2963/3000]: Train loss: 2.9849, Valid loss: 2.7517
# Epoch [2964/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 339.86it/s, loss=5.98]
# Epoch [2964/3000]: Train loss: 4.2720, Valid loss: 7.3025
# Epoch [2965/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 296.39it/s, loss=3.61]
# Epoch [2965/3000]: Train loss: 3.6696, Valid loss: 4.0421
# Epoch [2966/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 259.81it/s, loss=4.4]
# Epoch [2966/3000]: Train loss: 4.0753, Valid loss: 5.2319
# Epoch [2967/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 274.20it/s, loss=2.61]
# Epoch [2967/3000]: Train loss: 4.1093, Valid loss: 2.8249
# Epoch [2968/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 275.60it/s, loss=4.1]
# Epoch [2968/3000]: Train loss: 3.2146, Valid loss: 4.1524
# Epoch [2969/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 276.72it/s, loss=3.84]
# Epoch [2969/3000]: Train loss: 4.0398, Valid loss: 3.0497
# Epoch [2970/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 292.44it/s, loss=2.83]
# Epoch [2970/3000]: Train loss: 3.1686, Valid loss: 3.4185
# Epoch [2971/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 269.77it/s, loss=2.79]
# Epoch [2971/3000]: Train loss: 3.4572, Valid loss: 2.5325
# Epoch [2972/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 271.37it/s, loss=3.88]
# Epoch [2972/3000]: Train loss: 4.4139, Valid loss: 4.7331
# Epoch [2973/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 264.82it/s, loss=2.68]
# Epoch [2973/3000]: Train loss: 3.6608, Valid loss: 3.0865
# Epoch [2974/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 293.95it/s, loss=3.2]
# Epoch [2974/3000]: Train loss: 4.0528, Valid loss: 3.4112
# Epoch [2975/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 301.33it/s, loss=4.45]
# Epoch [2975/3000]: Train loss: 3.5052, Valid loss: 3.6617
# Epoch [2976/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 273.01it/s, loss=2.93]
# Epoch [2976/3000]: Train loss: 3.8898, Valid loss: 3.0216
# Epoch [2977/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 278.37it/s, loss=3.08]
# Epoch [2977/3000]: Train loss: 2.8163, Valid loss: 5.4634
# Epoch [2978/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 449.65it/s, loss=3.03]
# Epoch [2978/3000]: Train loss: 3.6325, Valid loss: 2.3642
# Epoch [2979/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 296.56it/s, loss=4.4]
# Epoch [2979/3000]: Train loss: 4.6404, Valid loss: 5.2804
# Epoch [2980/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 286.17it/s, loss=2.78]
# Epoch [2980/3000]: Train loss: 3.9072, Valid loss: 3.0065
# Epoch [2981/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 419.99it/s, loss=2.33]
# Epoch [2981/3000]: Train loss: 2.7138, Valid loss: 2.6193
# Epoch [2982/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 427.22it/s, loss=3.25]
# Epoch [2982/3000]: Train loss: 2.8334, Valid loss: 3.8537
# Epoch [2983/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 456.59it/s, loss=3.82]
# Epoch [2983/3000]: Train loss: 5.5391, Valid loss: 4.8556
# Epoch [2984/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 433.29it/s, loss=4.63]
# Epoch [2984/3000]: Train loss: 3.8233, Valid loss: 3.0112
# Epoch [2985/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 374.38it/s, loss=4.33]
# Epoch [2985/3000]: Train loss: 3.3764, Valid loss: 5.0837
# Epoch [2986/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 260.09it/s, loss=2.79]
# Epoch [2986/3000]: Train loss: 5.0480, Valid loss: 2.9710
# Epoch [2987/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 357.81it/s, loss=3.26]
# Epoch [2987/3000]: Train loss: 2.8512, Valid loss: 4.9422
# Epoch [2988/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 390.70it/s, loss=3.23]
# Epoch [2988/3000]: Train loss: 4.2325, Valid loss: 3.1622
# Epoch [2989/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 404.08it/s, loss=4.93]
# Epoch [2989/3000]: Train loss: 3.7456, Valid loss: 7.7041
# Epoch [2990/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 423.05it/s, loss=3.36]
# Epoch [2990/3000]: Train loss: 4.2069, Valid loss: 2.8871
# Epoch [2991/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 382.49it/s, loss=2.89]
# Epoch [2991/3000]: Train loss: 3.4612, Valid loss: 4.0804
# Epoch [2992/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 396.45it/s, loss=3.81]
# Epoch [2992/3000]: Train loss: 3.3310, Valid loss: 3.8272
# Epoch [2993/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 314.53it/s, loss=2.85]
# Epoch [2993/3000]: Train loss: 4.9295, Valid loss: 3.0605
# Epoch [2994/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 499.76it/s, loss=3.04]
# Epoch [2994/3000]: Train loss: 2.8799, Valid loss: 4.3086
# Epoch [2995/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 333.30it/s, loss=2.94]
# Epoch [2995/3000]: Train loss: 5.0893, Valid loss: 3.5731
# Epoch [2996/3000]: 100%|██████████████████████████████████████████████████████| 9/9 [00:00<00:00, 399.40it/s, loss=3.3]
# Epoch [2996/3000]: Train loss: 2.9740, Valid loss: 2.6592
# Epoch [2997/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 343.97it/s, loss=5.36]
# Epoch [2997/3000]: Train loss: 3.9056, Valid loss: 5.9082
# Epoch [2998/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 524.22it/s, loss=3.84]
# Epoch [2998/3000]: Train loss: 5.1040, Valid loss: 3.7340
# Epoch [2999/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 453.16it/s, loss=3.38]
# Epoch [2999/3000]: Train loss: 3.6978, Valid loss: 3.9133
# Epoch [3000/3000]: 100%|█████████████████████████████████████████████████████| 9/9 [00:00<00:00, 376.06it/s, loss=2.13]
# Epoch [3000/3000]: Train loss: 2.8570, Valid loss: 3.4801

# %% [markdown]
# # Plot learning curves with tensorboard (optional)

# %%
def save_pred(preds, file):
    '''将预测信息保存到特殊文件'''
    with open(file, 'w') as fp:
        writer = csv.writer(fp)
        writer.writerow(['id', 'tested_positive'])
        for i, p in enumerate(preds):
            writer.writerow([i, p])

# %%
model = My_Model(input_dim=x_train.shape[1]).to(device)
model.load_state_dict(torch.load(config['save_path']))
preds = predict(test_loader, model, device)
save_pred(preds, 'preds.csv')
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 681.03it/s]

# %%
preds
# Out:
# array([ 9.450252,  6.670342,  4.5637  , ..., 33.85092 , 34.50834 ,
#        36.12119 ], dtype=float32)

# %%
preds.shape
# Out:
# (1078,)

# %%
preds.ndim
# Out:
# 1

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize=(15,10))
plt.plot(range(1078),preds)
plt.show()
